# %%
from modules import *
# %load_ext autoreload
# %autoreload 2

# %%
raw_icm=mne.io.read_raw_fif('/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/raw/Data_neurospin/sub-03/run01_raw.fif', preload=True, allow_maxshield=True)

# %%
raw=mne.io.read_raw_fif('/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/raw/Data_ICM/sub-01/run01.fif', preload=True, allow_maxshield=True)
# Out:
# Opening raw data file /Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/raw/Data_neurospin/sub-03/run01_raw.fif...
#     Read a total of 13 projection items:
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#     Range : 10000 ... 505999 =     10.000 ...   505.999 secs
# Ready.
# Reading 0 ... 495999  =      0.000 ...   495.999 secs...
# ...

# %%
raw.info
# Out:
# <Info | 27 non-empty values
#  acq_pars: ACQactiveGround 1 ACQch.BIO001.gain 2000 ACQch.BIO001.highpass ...
#  bads: []
#  ch_names: EEG001, EEG002, EEG003, EEG004, EEG005, EEG006, EEG007, EEG008, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  description: TRIUX system at CEA-Saclay
#  dev_head_t: MEG device -> head transform
#  device_info: 4 items (dict)
#  dig: 32 items (3 Cardinal, 5 HPI, 24 Extra)
#  events: 1 item (list)
#  experimenter: MEGUSER (meguser)
#  gantry_angle: 68.0
#  helium_info: 2 items (dict)
#  highpass: 0.0 Hz
#  hpi_meas: 1 item (list)
#  hpi_results: 1 item (list)
#  hpi_subsystem: 3 items (dict)
#  line_freq: 50.0
#  lowpass: 330.0 Hz
#  maxshield: True
#  meas_date: 2024-06-28 07:37:02 UTC
#  meas_id: 4 items (dict)
#  nchan: 64
#  proc_history: 1 item (list)
#  proj_id: 1 item (ndarray)
#  proj_name: megseq
#  projs: []
#  sfreq: 1000.0 Hz
#  subject_info: 6 items (dict)
#  utc_offset: +02:00
# >

# %%
raw.pick_types(eeg=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 raw.pick(eeg=True)
#
# TypeError: pick() got an unexpected keyword argument 'eeg'

# %%
raw.info['ch_names']
# Out:
# ['EOG001',
#  'EOG002',
#  'ECG003',
#  'EEG001',
#  'EEG002',
#  'EEG003',
#  'EEG004',
#  'EEG005',
#  'EEG006',
#  'EEG007',
#  'EEG008',
#  'EEG009',
#  'EEG010',
#  'EEG011',
#  'EEG012',
#  'EEG013',
#  'EEG014',
#  'EEG015',
#  'EEG016',
#  'EEG017',
#  'EEG018',
#  'EEG019',
#  'EEG020',
#  'EEG021',
#  'EEG022',
#  'EEG023',
#  'EEG024',
#  'EEG025',
#  'EEG026',
#  'EEG027',
#  'EEG028',
#  'EEG029',
#  'EEG030',
#  'EEG031',
#  'EEG032',
#  'EEG033',
#  'EEG034',
#  'EEG035',
#  'EEG036',
#  'EEG037',
#  'EEG038',
#  'EEG039',
#  'EEG040',
#  'EEG041',
#  'EEG042',
#  'EEG043',
#  'EEG044',
#  'EEG045',
#  'EEG046',
#  'EEG047',
#  'EEG048',
#  'EEG049',
#  'EEG050',
#  'EEG051',
#  'EEG052',
#  'EEG053',
#  'EEG054',
#  'EEG055',
#  'EEG056',
#  'EEG057',
#  'EEG058',
#  'EEG059',
#  'EEG060',
#  'EEG061',
#  'EEG062',
#  'EEG063',
#  'EEG064',
#  'IASX+',
#  'IASX-',
#  'IASY+',
#  'IASY-',
#  'IASZ+',
#  'IASZ-',
#  'IAS_DX',
#  'IAS_DY',
#  'IAS_X',
#  'IAS_Y',
# ...

# %%
path_root="/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/raw"
path_json_file='modules/objects/bad_channels.json'

# %%
def prepare_json_bad_channels(file):
    
    with open('modules/objects/bda_channels.json', 'r') as file:
        bad_channels_dict=json.load(file)
    
    # Array will hold the lab for every subject
    arr_lab=[]
    return

# %%
with open(path_json_file, 'r') as file:
    bad_channels_dict=json.load(file)
bad_channels_dict
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[41], line 2
#       1 with open(path_json_file, 'r') as file:
# ----> 2     bad_channels_dict=json.load(file)
#
# File /opt/anaconda3/envs/mne_python/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# ...

# %%
bad_channels_dict
# Out:
# {'sub-01': {'lab': 'icm', 'run01': [], 'run02': [], 'run03': [], 'run04': []},
#  'sub-02': {},
#  'sub-03': {},
#  'sub-04': {},
#  'sub-05': {}}

# %%
# Update each subject with 18 runs
for sub in bad_channels_dict:
    if 'lab' in bad_channels_dict[sub]:
        lab_value = bad_channels_dict[sub]['lab']
    else:
        lab_value = 'neurospin'  # Provide a default lab value if needed
    bad_channels_dict[sub] = {f'run{str(i).zfill(2)}': [] for i in range(1, 19)}
    bad_channels_dict[sub]['lab'] = lab_value

# Output the modified dictionary
print(bad_channels_dict)

# Optionally, save the modified dictionary back to the JSON file
with open(path_json_file, 'w') as file:
    json.dump(bad_channels_dict, file, indent=4)
# Out:
# {'sub-01': {'run01': [], 'run02': [], 'run03': [], 'run04': [], 'run05': [], 'run06': [], 'run07': [], 'run08': [], 'run09': [], 'run10': [], 'run11': [], 'run12': [], 'run13': [], 'run14': [], 'run15': [], 'run16': [], 'run17': [], 'run18': [], 'lab': 'icm'}, 'sub-02': {'run01': [], 'run02': [], 'run03': [], 'run04': [], 'run05': [], 'run06': [], 'run07': [], 'run08': [], 'run09': [], 'run10': [], 'run11': [], 'run12': [], 'run13': [], 'run14': [], 'run15': [], 'run16': [], 'run17': [], 'run18': [], 'lab': 'default_lab_value'}, 'sub-03': {'run01': [], 'run02': [], 'run03': [], 'run04': [], 'run05': [], 'run06': [], 'run07': [], 'run08': [], 'run09': [], 'run10': [], 'run11': [], 'run12': [], 'run13': [], 'run14': [], 'run15': [], 'run16': [], 'run17': [], 'run18': [], 'lab': 'default_lab_value'}, 'sub-04': {'run01': [], 'run02': [], 'run03': [], 'run04': [], 'run05': [], 'run06': [], 'run07': [], 'run08': [], 'run09': [], 'run10': [], 'run11': [], 'run12': [], 'run13': [], 'run14': 
# ...

# %%
def prepare_json_bad_channels(path_json_file, sub):
    # Load the JSON file
    with open(path_json_file, 'r') as file:
        bad_channels_dict = json.load(file)
    
    # Create the subject key if it doesn't exist
    for k in range(sub):
        subject_key = f'sub-{k:02}'
        if subject_key not in bad_channels_dict:
            bad_channels_dict[subject_key] = {}
    
    # Update each subject with 18 runs
    for sub in bad_channels_dict:
        if 'lab' in bad_channels_dict[sub]:
            lab_value = bad_channels_dict[sub]['lab']
        else:
            lab_value = 'neurospin'  # Provide a default lab value if needed
        bad_channels_dict[sub] = {f'run{str(i).zfill(2)}': [] for i in range(1, 19)}
        bad_channels_dict[sub]['lab'] = lab_value

    # Optionally, save the modified dictionary back to the JSON file
    with open(path_json_file, 'w') as file:
        json.dump(bad_channels_dict, file, indent=4)

# %%
def prepare_json_bad_channels(path_json_file, sub):
    # Load the JSON file
    with open(path_json_file, 'r') as file:
        bad_channels_dict = json.load(file)
    
    # Create the subject key if it doesn't exist
    for k in range(1, sub + 1):
        subject_key = f'sub-{k:02}'
        if subject_key not in bad_channels_dict:
            bad_channels_dict[subject_key] = {}
    
    # Update each subject with 18 runs
    for subject_key in bad_channels_dict:
        if 'lab' in bad_channels_dict[subject_key]:
            lab_value = bad_channels_dict[subject_key]['lab']
        else:
            lab_value = 'neurospin'  # Provide a default lab value if needed
        bad_channels_dict[subject_key] = {f'run{str(i).zfill(2)}': [] for i in range(1, 19)}
        bad_channels_dict[subject_key]['lab'] = lab_value

    # Save the modified dictionary back to the JSON file
    with open(path_json_file, 'w') as file:
        json.dump(bad_channels_dict, file, indent=4)

# %%
prepare_json_bad_channels(path_json_file,10)

# %%
import mne
import os

# %%
path_root="/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/raw/Data_ICM/sub-02"

# %%
path_root_2="/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/raw/Data_neurospin/sub-05"

# %%
run=1

# %%
raw=mne.io.read_raw_fif(os.path.join(path_root_2,f'run{run:02}_raw.fif'),preload=True, allow_maxshield=True)
# Out:
# Opening raw data file /Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/raw/Data_neurospin/sub-05/run01_raw.fif...
#     Read a total of 13 projection items:
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#         generated with dossp-2.1 (1 x 306)  idle
#     Range : 15000 ... 499999 =     15.000 ...   499.999 secs
# Ready.
# Reading 0 ... 484999  =      0.000 ...   484.999 secs...
# ...

# %%
filt_raw=raw.filter(l_freq=0.1, h_freq=40.0)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 33001 samples (33.001 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    3.4s

# %%
filt_raw.plot()
# Out:
# <MNEBrowseFigure size 3024x1844 with 5 Axes>

# %%
# %matplotlib qt
raw.plot_sensors(kind='select',show=True, show_names=True, ch_groups=['MEG0221'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
# ----> 2 raw.plot_sensors(kind='select',show=True, show_names=True, ch_groups=['MEG0221'])
#
# File <decorator-gen-25>:12, in plot_sensors(self, kind, ch_type, title, show_names, ch_groups, to_sphere, axes, block, show, sphere, verbose)
#
# File /opt/anaconda3/envs/mne_python/lib/python3.9/site-packages/mne/_fiff/meas_info.py:753, in SetChannelsMixin.plot_sensors(self, kind, ch_type, title, show_names, ch_groups, to_sphere, axes, block, show, sphere, verbose)
#     682 """Plot sensor positions.
#     683
#     684 Parameters
#    (...)
#     749 .. versionadded:: 0.12.0
#     750 """
#     751 from ..viz.utils import plot_sensors
# --> 753 return plot_sensors(
#     754     self if isinstance(self, Info) else self.info,
#     755     kind=kind,
# ...

# %%
raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 3024x1844 with 5 Axes>

# %%
del raw

# %%
def send_to_json(path_json_file,sub,run):

# %%
import os

# %%
sub=1
run=1

# %%
path_root="/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data"
path_BIDS=os.path.join(path_root,'BIDS')
path_sub=os.path.join(path_BIDS,f'sub-{sub:02}')
path_run=os.path.join(path_sub,f'/meg/sub-{sub:02}_task-reproduction_run-{run:02}_meg.fif')

# %%
raw=mne.io.read_raw_fif(path_run, allow_maxshield=True, preload=True)
# Out:
# Opening raw data file /meg/sub-01_task-reproduction_run-01_meg.fif...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 raw=mne.io.read_raw_fif(path_run, allow_maxshield=True, preload=True)
#
# File /opt/anaconda3/envs/mne_python/lib/python3.9/site-packages/mne/io/fiff/raw.py:537, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     496 @fill_doc
#     497 def read_raw_fif(
#     498     fname, allow_maxshield=False, preload=False, on_split_missing="raise", verbose=None
#     499 ) -> Raw:
#     500     """Reader function for Raw FIF data.
#     501
#     502     Parameters
#    (...)
#     535     are updated accordingly.
#     536     """
# --> 537     return Raw(
#     538         fname=fname,
#     539         allow_maxshield=allow_maxshield,
#     540         preload=preload,
#     541         verbose=verbose,
# ...
